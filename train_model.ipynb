# %% [markdown]
# # Train Word2Vec

# %%
from gensim.models import Word2Vec
import logging
import os
import re
import time

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def walk_dir_paths(_dir):
    """Get paths to all files."""
    for root, directories, filenames in os.walk(_dir):
        for filename in filenames:
            yield os.path.join(root,filename)

def gen_sentences(corpus_path):
    """Open paths, return generator of a list of sentences."""
    comp_sent = re.compile(r'\.\s')
    comp_word = re.compile(r'[\W_]+')
    
    paths = walk_dir_paths(corpus_path)
    for path in paths:
        try:
            with open(path) as file_open:
                text = file_open.read()
            sentences = comp_sent.split(text)
        except Exception as e:
            pass
            
        # rm junk
        for sentence in sentences:
            words = comp_word.split(sentence.lower())
            sentence = [w for w in words if w if len(w) > 2]
            if sentence:
                yield sentence

# %%
all_enron = os.path.expanduser('~/Downloads/word2vec_stuff/maildir')  # 517401
enron_taylor = os.path.join(all_enron, 'taylor-m')  # 13875
enron_meyers = os.path.join(all_enron, 'meyers-a')  # 1099
enron_small = os.path.join(all_enron, 'taylor-m/uk_trading')  # 20

# %%
# what do the sentences look like?
counter = 0
for s in gen_sentences(enron_taylor):
    counter += 1
    if counter % 10000 == 0:
        print(s)
# Out:
# ['travel', 'schedule', 'pretty', 'tight', 'this', 'month', 'you', 'think', 'makes', 'sense', 'set', 'something', 'for', 'april', 'enron', 'north', 'america', 'corp']
# ['bryan', 'can', 'you', 'ask', 'mary', 'arrange', 'meeting', 'for', 'thurs', 'fri']
# ['alan', 'aronowitz', '2000', 'thomas', 'gros', 'enron', 'enron', 'mark', 'taylor', 'hou', 'ect', 'ect', 'todd', 'ballengee', 'enron', 'enron', 'leslie', 'reeves', 'hou', 'ect', 'ect', 'subject', 'commoditylogic', 'legal', 'docs', 'tom', 'the', 'eol', 'password', 'application', 'form', 'used', 'develop', 'the', 'commoditylogic', 'password', 'application', 'except', 'set', 'forth', 'below', 'identical', 'the', 'latest', 'version', 'the', 'eol', 'available', 'the', 'eol', 'website']
# ['http', 'www', 'amazon', 'com', 'your', 'account', 'thank', 'you', 'for', 'shopping', 'amazon', 'com', 'amazon', 'com', 'earth', 'biggest', 'selection', 'http', 'www', 'amazon', 'com', 'orders', 'amazon', 'com']
# ['message', '13841375', '1075860193430', 'javamail', 'evans', 'thyme', 'date', 'tue', 'feb', '2001', '0800', 'pst', 'from', 'mark', 'taylor', 'enron', 'com', 'stephanie', 'truss', 'enron', 'com', 'subject', 'moving', 'date', 'mime', 'version', 'content', 'type', 'text', 'plain', 'charset', 'ansi', '1968', 'content', 'transfer', 'encoding', 'quoted', 'printable', 'from', 'mark', 'taylor', 'stephanie', 'truss', 'bcc', 'folder', 'mark', 'taylor', 'jun2001', 'notes', 'folders', 'all', 'documents', 'origin', 'taylor', 'filename', 'mtaylor', 'nsf', 'stephanie', 'this', 'like', 'very', 'complicated', 'game', 'musical', 'chairs']
# ['aquila', 'energy', 'scott', 'eckerman', '816', '522', '1228', 'called', 'and', 'wanted', 'get', 'more', 'clear', 'wording', 'the', 'few', 'issues', 'the', 'eta']
# ['this', 'would', 'clearly', 'impact', 'the', 'settlement', 'the', 'transaction', 'particular', 'shorter', 'term', 'deals', 'sinc', 'reporting', 'and', 'approval', 'may', 'take', 'several', 'weeks']
# ['enron', 'recipients', 'akoehle', 'kraske', 'paul', 'enron', 'recipients', 'notesaddr', 'eaa3ab39', '55f71be1', '862568db', '523dba', 'krenz', 'william', 'enron', 'recipients', 'notesaddr', 'fcd567ae', 'a24c49c0', '86256783', '5157f5', 'leite', 'francisco', 'pinto', 'enron', 'recipients', 'fleite', 'lindeman', 'cheryl', 'enron', 'recipients', 'clindema', 'lundstrom', 'bruce', 'enron', 'recipients', 'notesaddr', '850f7bfb', '337864b2', '862566cc', '807509', 'lyons', 'dan', 'enron', 'recipients', 'dlyons', 'mann', 'kay', 'enron', 'recipients', 'kmann', 'martinez', 'vicky', 'enron', 'recipients', 'notesaddr', '6e73f7df', '963d27b5', '862568de', '72cbef', 'mathis', 'robert', 'enron', 'recipients', 'notesaddr', 'ee99a391', '1be6a8cb', '862568c5', '63d2ce', 'maynard', 'michelle', 'enron', 'recipients', 'notesaddr', '865badc0', '1006ba9f', '8625653f', '6179a1', 'mccarrel', 'steven', 'enron', 'recipients', 'smccarre', 'mccullough', 'travis', 'enron', 'recipients', 'tmccull', 'mcgrory', 'robert', 'enron', 'recipients', 'recipients', 'rmcgror', 'mellencamp', 'lisa', 'enron', 'recipients', 'lmellen', 'mendoza', 'miguel', 'enron', 'recipients', 'mmendoz3', 'moore', 'janet']
# ['few', 'years', 'ago', 'the', 'united', 'nations', 'estimated', 'that', 'there', 'are', '500', '000', 'disabled', 'orphans', 'afghanistan', 'country', 'with', 'economy', 'food']
# ['also', 'wanted', 'get', 'arcy', 'feedback', 'very', 'much', 'involved', 'with', 'eol', 'part']
# ['this', 'structural', 'error', 'that', 'was', 'carried', 'through', 'all', 'the', 'basis', 'swap', 'definitions', 'and', 'should', 'fixed', 'avoid', 'ambiguity', 'future', 'arguments', 'over', 'what', 'was', 'intended']
# ['but', 'was', 'not', 'able', 'access', 'the', 'actual', 'definition', 'unavailable', 'seconds', 'thru', 'the', 'www', 'ansi', 'org', 'website', 'but', 'someone', 'here', 'should', 'have', 'them']
# ['alan', 'mark', 'taylor', '2000', 'alan', 'aronowitz', 'hou', 'ect', 'ect', 'subject', 'alphatrust', 'providing', 'legal', 'framework', 'for', 'electronic', 'signatures', 'thought', 'you', 'might', 'interested', 'this']
# ['current', 'quarter', 'ends', 'february']
# ['you', 'won', 'finished', 'with', 'your', 'nails', 'until', 'saturday', 'and', 'then', 'there', 'the', 'law', 'school', 'bbq', 'and', 'amanda']
# ['regarding', 'transactions', 'which', 'epmi', 'may', 'purchasing', 'from', 'pge', 'through', 'enrononline', 'there', 'nothing', 'the', 'applicants', 'proposed', 'restrictions', 'that', 'would', 'require', 'pge', 'simultaneously', 'offer', 'sell', 'non', 'affiliates', 'the', 'same', 'rate', 'offered', 'the', 'affiliate']

# %%
model = Word2Vec(sentences=list(gen_sentences(enron_meyers)), size=8, window=5, min_count=5, workers=4)

# %%
for s in gen_sentences(enron_taylor):
    model.train(s)  # 5.6 min
# Out:
# 339.45538306236267

# %%
model.most_similar('friday')
# Out:
# [('hotmail', 0.968381404876709),
#  ('infrastructure', 0.9614548683166504),
#  ('linda', 0.9553625583648682),
#  ('thursday', 0.9542112350463867),
#  ('laid', 0.9515721797943115),
#  ('original', 0.9272415041923523),
#  ('mmeyers', 0.925380289554596),
#  ('january', 0.9249365329742432),
#  ('address', 0.9219551086425781),
#  ('how', 0.9138798117637634)]

# %%
model.vocab
# Out:
# {'continue': <gensim.models.word2vec.Vocab at 0x1077a2550>,
#  'completed': <gensim.models.word2vec.Vocab at 0x1077a25c0>,
#  'inform': <gensim.models.word2vec.Vocab at 0x1077cb1d0>,
#  'fsp': <gensim.models.word2vec.Vocab at 0x1077b3940>,
#  'moves': <gensim.models.word2vec.Vocab at 0x1077c63c8>,
#  'seems': <gensim.models.word2vec.Vocab at 0x1077a25f8>,
#  'htrinh': <gensim.models.word2vec.Vocab at 0x1077b39b0>,
#  'hsalisbu': <gensim.models.word2vec.Vocab at 0x1077d6198>,
#  'forster': <gensim.models.word2vec.Vocab at 0x1077a2630>,
#  'bharathi': <gensim.models.word2vec.Vocab at 0x1077b39e8>,
#  'brown': <gensim.models.word2vec.Vocab at 0x1077b3a20>,
#  'greg': <gensim.models.word2vec.Vocab at 0x1077b3a58>,
#  'name': <gensim.models.word2vec.Vocab at 0x1077a2668>,
#  'many': <gensim.models.word2vec.Vocab at 0x1077b3ac8>,
#  'trading': <gensim.models.word2vec.Vocab at 0x107791160>,
#  'guy': <gensim.models.word2vec.Vocab at 0x1077cbeb8>,
#  'else': <gensim.models.word2vec.Vocab at 0x1077b57b8>,
#  'term': <gensim.models.word2vec.Vocab at 0x1077c6438>,
#  'anthony': <gensim.models.word2vec.Vocab at 0x1077c6470>,
#  'floors': <gensim.models.word2vec.Vocab at 0x1077b3b00>,
#  'build': <gensim.models.word2vec.Vocab at 0x1077b3b38>,
#  'done': <gensim.models.word2vec.Vocab at 0x1077b3b70>,
#  'delete': <gensim.models.word2vec.Vocab at 0x1077b3ba8>,
#  'nothing': <gensim.models.word2vec.Vocab at 0x1077a26d8>,
#  'estoppel': <gensim.models.word2vec.Vocab at 0x10779df98>,
#  'policy': <gensim.models.word2vec.Vocab at 0x1077cb278>,
#  '800': <gensim.models.word2vec.Vocab at 0x1077a2710>,
#  'pass': <gensim.models.word2vec.Vocab at 0x1077a2748>,
#  'allow': <gensim.models.word2vec.Vocab at 0x1077b5d68>,
#  'sent': <gensim.models.word2vec.Vocab at 0x1077796d8>,
#  'settlement': <gensim.models.word2vec.Vocab at 0x1077955c0>,
#  'mburlei': <gensim.models.word2vec.Vocab at 0x1077b3c18>,
#  'cell': <gensim.models.word2vec.Vocab at 0x107779780>,
#  'victor': <gensim.models.word2vec.Vocab at 0x1077b3c50>,
#  'hanse': <gensim.models.word2vec.Vocab at 0x1077b3c88>,
#  'pmotuzko': <gensim.models.word2vec.Vocab at 0x1077b5908>,
#  'making': <gensim.models.word2vec.Vocab at 0x1077d0320>,
#  'walker': <gensim.models.word2vec.Vocab at 0x107779898>,
#  'julie': <gensim.models.word2vec.Vocab at 0x107779160>,
#  'every': <gensim.models.word2vec.Vocab at 0x1077a27b8>,
#  'december': <gensim.models.word2vec.Vocab at 0x1077a27f0>,
#  'attorneys': <gensim.models.word2vec.Vocab at 0x1077a2828>,
#  'andrea': <gensim.models.word2vec.Vocab at 0x1077a2860>,
#  'per': <gensim.models.word2vec.Vocab at 0x1077a2898>,
#  'vsorkina': <gensim.models.word2vec.Vocab at 0x1077b3cf8>,
#  'zone': <gensim.models.word2vec.Vocab at 0x1077c6710>,
#  'ricky': <gensim.models.word2vec.Vocab at 0x107779240>,
#  'jbharat': <gensim.models.word2vec.Vocab at 0x1077798d0>,
#  'llodra': <gensim.models.word2vec.Vocab at 0x1077c6550>,
#  'schitra': <gensim.models.word2vec.Vocab at 0x107779908>,
#  'america': <gensim.models.word2vec.Vocab at 0x107795c18>,
#  'khuntle': <gensim.models.word2vec.Vocab at 0x1077a5748>,
#  'protocol': <gensim.models.word2vec.Vocab at 0x1077c6588>,
#  'otherwise': <gensim.models.word2vec.Vocab at 0x1077c65c0>,
#  'susan': <gensim.models.word2vec.Vocab at 0x1077a28d0>,
#  'hillier': <gensim.models.word2vec.Vocab at 0x1077a2908>,
#  'online': <gensim.models.word2vec.Vocab at 0x1077d0438>,
#  'enough': <gensim.models.word2vec.Vocab at 0x1077b3d30>,
#  'pull': <gensim.models.word2vec.Vocab at 0x1065e7358>,
#  'things': <gensim.models.word2vec.Vocab at 0x1077b3978>,
#  'shift': <gensim.models.word2vec.Vocab at 0x1077a2940>,
#  'cbowlin': <gensim.models.word2vec.Vocab at 0x1077b3d68>,
#  'same': <gensim.models.word2vec.Vocab at 0x1065e7208>,
#  'immediately': <gensim.models.word2vec.Vocab at 0x107796048>,
#  'stephens': <gensim.models.word2vec.Vocab at 0x1077b3da0>,
#  'profile': <gensim.models.word2vec.Vocab at 0x1065e7080>,
#  'plain': <gensim.models.word2vec.Vocab at 0x1077b3dd8>,
#  'theizen': <gensim.models.word2vec.Vocab at 0x1077b3e10>,
#  'paul': <gensim.models.word2vec.Vocab at 0x1077b81d0>,
#  'felicia': <gensim.models.word2vec.Vocab at 0x1077b82b0>,
#  'believe': <gensim.models.word2vec.Vocab at 0x1077b3e48>,
#  'must': <gensim.models.word2vec.Vocab at 0x1065e7240>,
#  'bob': <gensim.models.word2vec.Vocab at 0x1077d2748>,
#  'amanda': <gensim.models.word2vec.Vocab at 0x1077963c8>,
#  'tana': <gensim.models.word2vec.Vocab at 0x1077c6630>,
#  '713': <gensim.models.word2vec.Vocab at 0x1077c6668>,
#  'swhite': <gensim.models.word2vec.Vocab at 0x1077c66a0>,
#  'van': <gensim.models.word2vec.Vocab at 0x1077cd6a0>,
#  'exmerge': <gensim.models.word2vec.Vocab at 0x1077b3e80>,
#  'subject': <gensim.models.word2vec.Vocab at 0x1077a29b0>,
#  'sday': <gensim.models.word2vec.Vocab at 0x1077b8780>,
#  'version': <gensim.models.word2vec.Vocab at 0x1077c66d8>,
#  'dscholt': <gensim.models.word2vec.Vocab at 0x1077a29e8>,
#  'out': <gensim.models.word2vec.Vocab at 0x1077a2a20>,
#  'lwente': <gensim.models.word2vec.Vocab at 0x1077c6748>,
#  'thome': <gensim.models.word2vec.Vocab at 0x1077c6780>,
#  'edi': <gensim.models.word2vec.Vocab at 0x1077b8940>,
#  'pipeline': <gensim.models.word2vec.Vocab at 0x1077c67b8>,
#  'charles': <gensim.models.word2vec.Vocab at 0x1077b3eb8>,
#  'mheard': <gensim.models.word2vec.Vocab at 0x1077b89b0>,
#  'exercise': <gensim.models.word2vec.Vocab at 0x1077a2a58>,
#  'mead': <gensim.models.word2vec.Vocab at 0x1077b3a90>,
#  'rosendahl': <gensim.models.word2vec.Vocab at 0x1077a2a90>,
#  'update': <gensim.models.word2vec.Vocab at 0x10778d048>,
#  'angela': <gensim.models.word2vec.Vocab at 0x1077b3ef0>,
#  'contact': <gensim.models.word2vec.Vocab at 0x107791400>,
#  'thompson': <gensim.models.word2vec.Vocab at 0x107791390>,
#  'warburg': <gensim.models.word2vec.Vocab at 0x107779a20>,
#  'desk': <gensim.models.word2vec.Vocab at 0x1077b3f98>,
#  'attempted': <gensim.models.word2vec.Vocab at 0x1077c67f0>,
#  'them': <gensim.models.word2vec.Vocab at 0x107791e10>,
#  'schoppe': <gensim.models.word2vec.Vocab at 0x107796c50>,
#  'jane': <gensim.models.word2vec.Vocab at 0x1077b5048>,
#  'detected': <gensim.models.word2vec.Vocab at 0x1077a2b38>,
#  'malowney': <gensim.models.word2vec.Vocab at 0x1077c6828>,
#  'errigo': <gensim.models.word2vec.Vocab at 0x1077b8e10>,
#  'valuable': <gensim.models.word2vec.Vocab at 0x1077a2b70>,
#  'scranda': <gensim.models.word2vec.Vocab at 0x1077a2ba8>,
#  'users': <gensim.models.word2vec.Vocab at 0x1077d2128>,
#  'well': <gensim.models.word2vec.Vocab at 0x1077a2be0>,
#  'date': <gensim.models.word2vec.Vocab at 0x1077a2c18>,
#  'all': <gensim.models.word2vec.Vocab at 0x1077a2c50>,
#  'even': <gensim.models.word2vec.Vocab at 0x107791fd0>,
#  'united': <gensim.models.word2vec.Vocab at 0x107796f98>,
#  'tranny': <gensim.models.word2vec.Vocab at 0x1077a2c88>,
#  '09michael': <gensim.models.word2vec.Vocab at 0x1077b50b8>,
#  'bpa': <gensim.models.word2vec.Vocab at 0x107793278>,
#  'belden': <gensim.models.word2vec.Vocab at 0x1077b50f0>,
#  'jpostle': <gensim.models.word2vec.Vocab at 0x1077b5128>,
#  'include': <gensim.models.word2vec.Vocab at 0x1077b5e10>,
#  'portlandworldtradecenter': <gensim.models.word2vec.Vocab at 0x1077935c0>,
#  'empty': <gensim.models.word2vec.Vocab at 0x107793fd0>,
#  'paths': <gensim.models.word2vec.Vocab at 0x1077d04e0>,
#  'pge3': <gensim.models.word2vec.Vocab at 0x1077b5160>,
#  'furthermore': <gensim.models.word2vec.Vocab at 0x107798470>,
#  'feb': <gensim.models.word2vec.Vocab at 0x1077a2cf8>,
#  'purchased': <gensim.models.word2vec.Vocab at 0x1077c32b0>,
#  'sullivan': <gensim.models.word2vec.Vocab at 0x1077930b8>,
#  'corry': <gensim.models.word2vec.Vocab at 0x1077950f0>,
#  'chatterton': <gensim.models.word2vec.Vocab at 0x107795128>,
#  'bert': <gensim.models.word2vec.Vocab at 0x1077d64e0>,
#  'mark': <gensim.models.word2vec.Vocab at 0x1077b51d0>,
#  'les': <gensim.models.word2vec.Vocab at 0x107798710>,
#  'would': <gensim.models.word2vec.Vocab at 0x1077ba550>,
#  'another': <gensim.models.word2vec.Vocab at 0x1077c68d0>,
#  'dale': <gensim.models.word2vec.Vocab at 0x107795160>,
#  'sswain': <gensim.models.word2vec.Vocab at 0x1077b5208>,
#  'sept': <gensim.models.word2vec.Vocab at 0x107798828>,
#  'specific': <gensim.models.word2vec.Vocab at 0x1077ba6a0>,
#  'dluu': <gensim.models.word2vec.Vocab at 0x1077a2d30>,
#  'environments': <gensim.models.word2vec.Vocab at 0x1077a2d68>,
#  'eap': <gensim.models.word2vec.Vocab at 0x1077a7860>,
#  'epmi': <gensim.models.word2vec.Vocab at 0x1077a2dd8>,
#  'above': <gensim.models.word2vec.Vocab at 0x1077951d0>,
#  'can': <gensim.models.word2vec.Vocab at 0x107795208>,
#  'conference': <gensim.models.word2vec.Vocab at 0x107795240>,
#  'sat': <gensim.models.word2vec.Vocab at 0x1077b5278>,
#  'moyez': <gensim.models.word2vec.Vocab at 0x1077a2e10>,
#  'dbailey2': <gensim.models.word2vec.Vocab at 0x107795278>,
#  'reasoner': <gensim.models.word2vec.Vocab at 0x1077952b0>,
#  'termination': <gensim.models.word2vec.Vocab at 0x1077c8d30>,
#  'monica': <gensim.models.word2vec.Vocab at 0x107798dd8>,
#  'document': <gensim.models.word2vec.Vocab at 0x1077b52e8>,
#  'twalker3': <gensim.models.word2vec.Vocab at 0x1077a2e48>,
#  'aug': <gensim.models.word2vec.Vocab at 0x1077b5320>,
#  'jan': <gensim.models.word2vec.Vocab at 0x107795320>,
#  'global': <gensim.models.word2vec.Vocab at 0x1077a2e80>,
#  '853': <gensim.models.word2vec.Vocab at 0x1077b5358>,
#  'interim': <gensim.models.word2vec.Vocab at 0x1077b5390>,
#  'outside': <gensim.models.word2vec.Vocab at 0x1077a2eb8>,
#  'jon': <gensim.models.word2vec.Vocab at 0x107795358>,
#  'suz': <gensim.models.word2vec.Vocab at 0x1077a2ef0>,
#  'achampi': <gensim.models.word2vec.Vocab at 0x1077b5400>,
#  'asindwan': <gensim.models.word2vec.Vocab at 0x1077a2f28>,
#  'sean': <gensim.models.word2vec.Vocab at 0x107795390>,
#  'dave': <gensim.models.word2vec.Vocab at 0x1077953c8>,
#  'create': <gensim.models.word2vec.Vocab at 0x1077d2588>,
#  'own': <gensim.models.word2vec.Vocab at 0x1077b5470>,
#  'terminated': <gensim.models.word2vec.Vocab at 0x1077a2f60>,
#  'tantra': <gensim.models.word2vec.Vocab at 0x1077c80f0>,
#  'midtown': <gensim.models.word2vec.Vocab at 0x1077a2f98>,
#  'janders3': <gensim.models.word2vec.Vocab at 0x1077a2fd0>,
#  'made': <gensim.models.word2vec.Vocab at 0x1077bd1d0>,
#  'louise': <gensim.models.word2vec.Vocab at 0x1077a7c50>,
#  'johnston': <gensim.models.word2vec.Vocab at 0x1077c3518>,
#  'porter': <gensim.models.word2vec.Vocab at 0x1077c6a20>,
#  'only': <gensim.models.word2vec.Vocab at 0x10779a710>,
#  '100': <gensim.models.word2vec.Vocab at 0x1077cb400>,
#  'jelbert': <gensim.models.word2vec.Vocab at 0x10779a7b8>,
#  'ritacco': <gensim.models.word2vec.Vocab at 0x1077b54e0>,
#  'molly': <gensim.models.word2vec.Vocab at 0x1077a50b8>,
#  'amador': <gensim.models.word2vec.Vocab at 0x1077954a8>,
#  'participate': <gensim.models.word2vec.Vocab at 0x1077aa9e8>,
#  'risk': <gensim.models.word2vec.Vocab at 0x1077b3f60>,
#  'mmeyers': <gensim.models.word2vec.Vocab at 0x1077954e0>,
#  'others': <gensim.models.word2vec.Vocab at 0x107795518>,
#  'ring': <gensim.models.word2vec.Vocab at 0x1077c6a58>,
#  'wong': <gensim.models.word2vec.Vocab at 0x1077c6a90>,
#  'tianri': <gensim.models.word2vec.Vocab at 0x1077b55c0>,
#  'price': <gensim.models.word2vec.Vocab at 0x1077b55f8>,
#  'tuesday': <gensim.models.word2vec.Vocab at 0x107795550>,
#  'sengupta': <gensim.models.word2vec.Vocab at 0x107795588>,
#  'meet': <gensim.models.word2vec.Vocab at 0x1077bf4a8>,
#  'filename': <gensim.models.word2vec.Vocab at 0x1077b5630>,
#  'merriss': <gensim.models.word2vec.Vocab at 0x1077c6ac8>,
#  'verify': <gensim.models.word2vec.Vocab at 0x1077b5668>,
#  'cut': <gensim.models.word2vec.Vocab at 0x1077b56a0>,
#  'more': <gensim.models.word2vec.Vocab at 0x1077c6b00>,
#  'basis': <gensim.models.word2vec.Vocab at 0x1077aa908>,
#  'hawthorn': <gensim.models.word2vec.Vocab at 0x1077d2908>,
#  'berger': <gensim.models.word2vec.Vocab at 0x107798f60>,
#  'too': <gensim.models.word2vec.Vocab at 0x1077b56d8>,
#  'katie': <gensim.models.word2vec.Vocab at 0x1077c6b38>,
#  'file': <gensim.models.word2vec.Vocab at 0x1077c6b70>,
#  'judge': <gensim.models.word2vec.Vocab at 0x1077c64e0>,
#  'wsmith': <gensim.models.word2vec.Vocab at 0x1077b5710>,
#  'reports': <gensim.models.word2vec.Vocab at 0x1077b5748>,
#  '0700': <gensim.models.word2vec.Vocab at 0x1077a5160>,
#  'without': <gensim.models.word2vec.Vocab at 0x1077a2780>,
#  'afitzpat': <gensim.models.word2vec.Vocab at 0x1077b5780>,
#  'final': <gensim.models.word2vec.Vocab at 0x1077b8198>,
#  'someone': <gensim.models.word2vec.Vocab at 0x1077955f8>,
#  'jlewis9': <gensim.models.word2vec.Vocab at 0x1077a5198>,
#  'evans': <gensim.models.word2vec.Vocab at 0x1077a51d0>,
#  'rnolte': <gensim.models.word2vec.Vocab at 0x107795630>,
#  'hodges': <gensim.models.word2vec.Vocab at 0x1077ba358>,
#  'back': <gensim.models.word2vec.Vocab at 0x1077a5240>,
#  'mollie': <gensim.models.word2vec.Vocab at 0x107795668>,
#  'claim': <gensim.models.word2vec.Vocab at 0x1077d62e8>,
#  'stephanie': <gensim.models.word2vec.Vocab at 0x1077d0588>,
#  'dang': <gensim.models.word2vec.Vocab at 0x1077956a0>,
#  'houston': <gensim.models.word2vec.Vocab at 0x1077956d8>,
#  'wwp': <gensim.models.word2vec.Vocab at 0x10779d2b0>,
#  'positions': <gensim.models.word2vec.Vocab at 0x1077bd3c8>,
#  'casey': <gensim.models.word2vec.Vocab at 0x1077b5f28>,
#  'folder': <gensim.models.word2vec.Vocab at 0x1077b5828>,
#  'milk': <gensim.models.word2vec.Vocab at 0x107798550>,
#  'thursday': <gensim.models.word2vec.Vocab at 0x1077cb6d8>,
#  '50mw': <gensim.models.word2vec.Vocab at 0x1077b5860>,
#  'vpatel': <gensim.models.word2vec.Vocab at 0x107795780>,
#  'today': <gensim.models.word2vec.Vocab at 0x1077a52b0>,
#  'saw': <gensim.models.word2vec.Vocab at 0x1077b5898>,
#  'scheduling': <gensim.models.word2vec.Vocab at 0x1077a52e8>,
#  'king': <gensim.models.word2vec.Vocab at 0x1077b58d0>,
#  'mswaim': <gensim.models.word2vec.Vocab at 0x1077c6c18>,
#  'location': <gensim.models.word2vec.Vocab at 0x1077c6c50>,
#  'concern': <gensim.models.word2vec.Vocab at 0x1077957b8>,
#  'path': <gensim.models.word2vec.Vocab at 0x1077d2630>,
#  'x8321': <gensim.models.word2vec.Vocab at 0x1077b5978>,
#  'lreeves': <gensim.models.word2vec.Vocab at 0x10779d780>,
#  'legal': <gensim.models.word2vec.Vocab at 0x1077957f0>,
#  'old': <gensim.models.word2vec.Vocab at 0x1077a5320>,
#  'linda': <gensim.models.word2vec.Vocab at 0x1077a0588>,
#  'ectstca': <gensim.models.word2vec.Vocab at 0x107795828>,
#  'interview': <gensim.models.word2vec.Vocab at 0x1077b5a20>,
#  'everyone': <gensim.models.word2vec.Vocab at 0x1077c6cc0>,
#  'woman': <gensim.models.word2vec.Vocab at 0x1077a5358>,
#  'sheet': <gensim.models.word2vec.Vocab at 0x1077a5390>,
#  'northern': <gensim.models.word2vec.Vocab at 0x1077a53c8>,
#  'group': <gensim.models.word2vec.Vocab at 0x107795860>,
#  'atcfinalcomp': <gensim.models.word2vec.Vocab at 0x1077b5a90>,
#  'think': <gensim.models.word2vec.Vocab at 0x1077a5400>,
#  'other': <gensim.models.word2vec.Vocab at 0x1077d2240>,
#  'encoding': <gensim.models.word2vec.Vocab at 0x1077d2668>,
#  'parties': <gensim.models.word2vec.Vocab at 0x1077b3cc0>,
#  'cover': <gensim.models.word2vec.Vocab at 0x1077c6d30>,
#  'told': <gensim.models.word2vec.Vocab at 0x1077a5438>,
#  'issues': <gensim.models.word2vec.Vocab at 0x107795898>,
#  'joining': <gensim.models.word2vec.Vocab at 0x1077958d0>,
#  'cheung': <gensim.models.word2vec.Vocab at 0x1077c6d68>,
#  'driscoll': <gensim.models.word2vec.Vocab at 0x1077c6da0>,
#  'zero': <gensim.models.word2vec.Vocab at 0x1077cb4a8>,
#  'mritacco': <gensim.models.word2vec.Vocab at 0x1077c6dd8>,
#  'fcornr': <gensim.models.word2vec.Vocab at 0x1077c6e10>,
#  'schneider': <gensim.models.word2vec.Vocab at 0x1077c8518>,
#  'www': <gensim.models.word2vec.Vocab at 0x1077c6e48>,
#  'pplatte': <gensim.models.word2vec.Vocab at 0x107795908>,
#  '1411': <gensim.models.word2vec.Vocab at 0x107795940>,
#  'anwar': <gensim.models.word2vec.Vocab at 0x107795978>,
#  'mrobert6': <gensim.models.word2vec.Vocab at 0x1077c6be0>,
#  'head': <gensim.models.word2vec.Vocab at 0x1077959b0>,
#  'book': <gensim.models.word2vec.Vocab at 0x1077d0668>,
#  'pick': <gensim.models.word2vec.Vocab at 0x1077a5470>,
#  'marie': <gensim.models.word2vec.Vocab at 0x1077959e8>,
#  'schomer': <gensim.models.word2vec.Vocab at 0x1077a54e0>,
#  'lim': <gensim.models.word2vec.Vocab at 0x1077a5518>,
#  'lou': <gensim.models.word2vec.Vocab at 0x107795a20>,
#  'worldwide1': <gensim.models.word2vec.Vocab at 0x1077c3438>,
#  'gramesh': <gensim.models.word2vec.Vocab at 0x1077a5550>,
#  'board': <gensim.models.word2vec.Vocab at 0x1077a5588>,
#  'delivery': <gensim.models.word2vec.Vocab at 0x107795a58>,
#  'integrated': <gensim.models.word2vec.Vocab at 0x1077b5ac8>,
#  'man': <gensim.models.word2vec.Vocab at 0x1077a55c0>,
#  'allen': <gensim.models.word2vec.Vocab at 0x1077b5b00>,
#  'state': <gensim.models.word2vec.Vocab at 0x1077b5b38>,
#  'committee': <gensim.models.word2vec.Vocab at 0x1077bd390>,
#  'nearly': <gensim.models.word2vec.Vocab at 0x1077c3940>,
#  'apx': <gensim.models.word2vec.Vocab at 0x107795a90>,
#  'boudreaux': <gensim.models.word2vec.Vocab at 0x1077c3a20>,
#  'place': <gensim.models.word2vec.Vocab at 0x1077d0be0>,
#  'dharrel': <gensim.models.word2vec.Vocab at 0x1077c6f98>,
#  'companies': <gensim.models.word2vec.Vocab at 0x1077b5b70>,
#  'darren': <gensim.models.word2vec.Vocab at 0x1077b5ba8>,
#  'try': <gensim.models.word2vec.Vocab at 0x1077ba048>,
#  'problem': <gensim.models.word2vec.Vocab at 0x107795ac8>,
#  'said': <gensim.models.word2vec.Vocab at 0x1077c6fd0>,
#  'evite': <gensim.models.word2vec.Vocab at 0x1077a5908>,
#  'soon': <gensim.models.word2vec.Vocab at 0x107795b38>,
#  'semperger': <gensim.models.word2vec.Vocab at 0x1077c8080>,
#  'pena': <gensim.models.word2vec.Vocab at 0x1077b5be0>,
#  'houten': <gensim.models.word2vec.Vocab at 0x1077b5c18>,
#  'benefits': <gensim.models.word2vec.Vocab at 0x1077a55f8>,
#  'ectstnw': <gensim.models.word2vec.Vocab at 0x107795b70>,
#  'ken': <gensim.models.word2vec.Vocab at 0x107795ba8>,
#  'ect': <gensim.models.word2vec.Vocab at 0x107795be0>,
#  'send': <gensim.models.word2vec.Vocab at 0x1077a5630>,
#  'anyway': <gensim.models.word2vec.Vocab at 0x1077b5c50>,
#  'choate': <gensim.models.word2vec.Vocab at 0x1077b5c88>,
#  'amount': <gensim.models.word2vec.Vocab at 0x1077a5668>,
#  'details': <gensim.models.word2vec.Vocab at 0x107795c88>,
#  'wholesale': <gensim.models.word2vec.Vocab at 0x107795cc0>,
#  'parking': <gensim.models.word2vec.Vocab at 0x107795cf8>,
#  'mzheng': <gensim.models.word2vec.Vocab at 0x1077b5cc0>,
#  'make': <gensim.models.word2vec.Vocab at 0x1077a56d8>,
#  'piyush': <gensim.models.word2vec.Vocab at 0x107795d68>,
#  'harasin': <gensim.models.word2vec.Vocab at 0x1077b5d30>,
#  'her': <gensim.models.word2vec.Vocab at 0x1077c64a8>,
#  'confirmed': <gensim.models.word2vec.Vocab at 0x1077a5710>,
#  'jatinder': <gensim.models.word2vec.Vocab at 0x1077acda0>,
#  'dcutsfor': <gensim.models.word2vec.Vocab at 0x1077b5da0>,
#  'great': <gensim.models.word2vec.Vocab at 0x107795dd8>,
#  'shall4': <gensim.models.word2vec.Vocab at 0x1077cd748>,
#  'notify': <gensim.models.word2vec.Vocab at 0x107795e10>,
#  'sitara': <gensim.models.word2vec.Vocab at 0x1077a5780>,
#  'new': <gensim.models.word2vec.Vocab at 0x107795e48>,
#  'prohibited': <gensim.models.word2vec.Vocab at 0x1077ac2b0>,
#  'when': <gensim.models.word2vec.Vocab at 0x1077c8160>,
#  'these': <gensim.models.word2vec.Vocab at 0x1077b5dd8>,
#  'tonight': <gensim.models.word2vec.Vocab at 0x107795e80>,
#  'closing': <gensim.models.word2vec.Vocab at 0x10779d438>,
#  'mpc': <gensim.models.word2vec.Vocab at 0x1077c8198>,
#  'don': <gensim.models.word2vec.Vocab at 0x1077c8208>,
#  'screen': <gensim.models.word2vec.Vocab at 0x1077b5e48>,
#  'release': <gensim.models.word2vec.Vocab at 0x1077a57b8>,
#  'messages': <gensim.models.word2vec.Vocab at 0x1077a57f0>,
#  'table': <gensim.models.word2vec.Vocab at 0x1077b5e80>,
#  'sbennet': <gensim.models.word2vec.Vocab at 0x1077b5eb8>,
#  'overview': <gensim.models.word2vec.Vocab at 0x1077a5128>,
#  'bank': <gensim.models.word2vec.Vocab at 0x107795eb8>,
#  'review': <gensim.models.word2vec.Vocab at 0x1077a0748>,
#  'bmeyers': <gensim.models.word2vec.Vocab at 0x107795ef0>,
#  'jchatter': <gensim.models.word2vec.Vocab at 0x1077a5278>,
#  'west': <gensim.models.word2vec.Vocab at 0x1077b5f60>,
#  'regards': <gensim.models.word2vec.Vocab at 0x1077b5f98>,
#  'engy': <gensim.models.word2vec.Vocab at 0x1077c8240>,
#  'manual': <gensim.models.word2vec.Vocab at 0x107795f28>,
#  'thu': <gensim.models.word2vec.Vocab at 0x107795f60>,
#  'portlandvolumemgmt': <gensim.models.word2vec.Vocab at 0x1077c6e80>,
#  '3wtc': <gensim.models.word2vec.Vocab at 0x1077a5978>,
#  'soh2': <gensim.models.word2vec.Vocab at 0x1077c6f60>,
#  'thomas': <gensim.models.word2vec.Vocab at 0x107795438>,
#  'sivakumar': <gensim.models.word2vec.Vocab at 0x1077a5828>,
#  '3001': <gensim.models.word2vec.Vocab at 0x1077a5860>,
#  'gang': <gensim.models.word2vec.Vocab at 0x107798240>,
#  'down': <gensim.models.word2vec.Vocab at 0x1077a58d0>,
#  'important': <gensim.models.word2vec.Vocab at 0x1077a56a0>,
#  'but': <gensim.models.word2vec.Vocab at 0x107795fd0>,
#  'order': <gensim.models.word2vec.Vocab at 0x1077b5fd0>,
#  'added': <gensim.models.word2vec.Vocab at 0x1077b8048>,
#  'benefit': <gensim.models.word2vec.Vocab at 0x1077cb5f8>,
#  'policies': <gensim.models.word2vec.Vocab at 0x1077a5940>,
#  'better': <gensim.models.word2vec.Vocab at 0x1077b8080>,
#  'fsulisti': <gensim.models.word2vec.Vocab at 0x1077b80b8>,
#  'took': <gensim.models.word2vec.Vocab at 0x1077c8320>,
#  'jhenry6': <gensim.models.word2vec.Vocab at 0x1077b80f0>,
#  'bkandasw': <gensim.models.word2vec.Vocab at 0x1077aa4a8>,
#  'net': <gensim.models.word2vec.Vocab at 0x1077a59e8>,
#  'reimbursement': <gensim.models.word2vec.Vocab at 0x1077d2400>,
#  'ben': <gensim.models.word2vec.Vocab at 0x1077b8128>,
#  'scholtes': <gensim.models.word2vec.Vocab at 0x1077c65f8>,
#  'kinkead': <gensim.models.word2vec.Vocab at 0x107796080>,
#  'mbx': <gensim.models.word2vec.Vocab at 0x1077960f0>,
#  'padron': <gensim.models.word2vec.Vocab at 0x1077aad30>,
#  'meeting': <gensim.models.word2vec.Vocab at 0x1077c8358>,
#  'major': <gensim.models.word2vec.Vocab at 0x107796128>,
#  'advertising': <gensim.models.word2vec.Vocab at 0x1077a5a20>,
#  'pre': <gensim.models.word2vec.Vocab at 0x107796160>,
#  'macphail': <gensim.models.word2vec.Vocab at 0x1077c8390>,
#  'edward': <gensim.models.word2vec.Vocab at 0x107796198>,
#  'related': <gensim.models.word2vec.Vocab at 0x1077a5d68>,
#  'first': <gensim.models.word2vec.Vocab at 0x1077a5a58>,
#  'kenneth': <gensim.models.word2vec.Vocab at 0x1077a5a90>,
#  'use': <gensim.models.word2vec.Vocab at 0x1077a5ac8>,
#  'complete': <gensim.models.word2vec.Vocab at 0x1077c6860>,
#  'tue': <gensim.models.word2vec.Vocab at 0x1077c83c8>,
#  'employees': <gensim.models.word2vec.Vocab at 0x1077c8400>,
#  'ccheung': <gensim.models.word2vec.Vocab at 0x1077a5b00>,
#  'advisors': <gensim.models.word2vec.Vocab at 0x1077a5b38>,
#  'read': <gensim.models.word2vec.Vocab at 0x1077961d0>,
#  'groups': <gensim.models.word2vec.Vocab at 0x1077c6390>,
#  'ladwp': <gensim.models.word2vec.Vocab at 0x1077b8208>,
#  'ubspainewebber': <gensim.models.word2vec.Vocab at 0x1077baac8>,
#  'relied': <gensim.models.word2vec.Vocab at 0x1077b8240>,
#  'jeff': <gensim.models.word2vec.Vocab at 0x1077b8278>,
#  'wednesday': <gensim.models.word2vec.Vocab at 0x1077c8a58>,
#  'hey': <gensim.models.word2vec.Vocab at 0x107796240>,
#  'tie': <gensim.models.word2vec.Vocab at 0x1077b82e8>,
#  'dewett': <gensim.models.word2vec.Vocab at 0x1077b8320>,
#  'nov': <gensim.models.word2vec.Vocab at 0x1077a0828>,
#  'access': <gensim.models.word2vec.Vocab at 0x1077c84a8>,
#  'phanse': <gensim.models.word2vec.Vocab at 0x10779d588>,
#  'pasting': <gensim.models.word2vec.Vocab at 0x1077a5b70>,
#  'revised': <gensim.models.word2vec.Vocab at 0x1077a5ba8>,
#  'moore': <gensim.models.word2vec.Vocab at 0x1077962b0>,
#  'share': <gensim.models.word2vec.Vocab at 0x1077aada0>,
#  'room': <gensim.models.word2vec.Vocab at 0x1077b8358>,
#  'reached': <gensim.models.word2vec.Vocab at 0x1077a5be0>,
#  'sally': <gensim.models.word2vec.Vocab at 0x1077962e8>,
#  'family': <gensim.models.word2vec.Vocab at 0x1077accc0>,
#  'issue': <gensim.models.word2vec.Vocab at 0x1077b83c8>,
#  'prior': <gensim.models.word2vec.Vocab at 0x1077a2da0>,
#  'bentley': <gensim.models.word2vec.Vocab at 0x107796320>,
#  'sinha': <gensim.models.word2vec.Vocab at 0x1077b8400>,
#  'mallory': <gensim.models.word2vec.Vocab at 0x107796358>,
#  'jcashion': <gensim.models.word2vec.Vocab at 0x1077a5c18>,
#  'crawler': <gensim.models.word2vec.Vocab at 0x1077a5c50>,
#  'security': <gensim.models.word2vec.Vocab at 0x1077a5c88>,
#  'etringer': <gensim.models.word2vec.Vocab at 0x1077c85f8>,
#  'potential': <gensim.models.word2vec.Vocab at 0x1077a5cc0>,
#  'ganapathy': <gensim.models.word2vec.Vocab at 0x1077a5cf8>,
#  'rslinger': <gensim.models.word2vec.Vocab at 0x1077c8630>,
#  'ndattani': <gensim.models.word2vec.Vocab at 0x1077b8438>,
#  'adavis4': <gensim.models.word2vec.Vocab at 0x1077b84a8>,
#  'tolerance': <gensim.models.word2vec.Vocab at 0x1077cd550>,
#  'load': <gensim.models.word2vec.Vocab at 0x107796438>,
#  'signed': <gensim.models.word2vec.Vocab at 0x1077b84e0>,
#  'bowen': <gensim.models.word2vec.Vocab at 0x1077a5d30>,
#  '3rd': <gensim.models.word2vec.Vocab at 0x1077b8550>,
#  'check': <gensim.models.word2vec.Vocab at 0x1077a7be0>,
#  'lester': <gensim.models.word2vec.Vocab at 0x1077b85c0>,
#  'reportdate': <gensim.models.word2vec.Vocab at 0x1077c8668>,
#  'attached': <gensim.models.word2vec.Vocab at 0x107796470>,
#  'losses': <gensim.models.word2vec.Vocab at 0x1077964a8>,
#  'sold': <gensim.models.word2vec.Vocab at 0x1077b8630>,
#  'rennu': <gensim.models.word2vec.Vocab at 0x1077a2198>,
#  'swerzbin': <gensim.models.word2vec.Vocab at 0x1077a5da0>,
#  'dvinson': <gensim.models.word2vec.Vocab at 0x1077c86a0>,
#  'snewkirk': <gensim.models.word2vec.Vocab at 0x1077c86d8>,
#  'netco': <gensim.models.word2vec.Vocab at 0x1077a5dd8>,
#  'ectstsw': <gensim.models.word2vec.Vocab at 0x1077a5e10>,
#  'style': <gensim.models.word2vec.Vocab at 0x1077cba58>,
#  'were': <gensim.models.word2vec.Vocab at 0x1077b8668>,
#  'she': <gensim.models.word2vec.Vocab at 0x1077a5e48>,
#  'lkitchen': <gensim.models.word2vec.Vocab at 0x1077b86d8>,
#  'calcagno': <gensim.models.word2vec.Vocab at 0x1077b8710>,
#  'pmakkai': <gensim.models.word2vec.Vocab at 0x1077a5e80>,
#  'hope': <gensim.models.word2vec.Vocab at 0x1077c8710>,
#  'pinto': <gensim.models.word2vec.Vocab at 0x10779a160>,
#  'cmallor': <gensim.models.word2vec.Vocab at 0x1077a5eb8>,
#  'fallon': <gensim.models.word2vec.Vocab at 0x1077c8748>,
#  'used': <gensim.models.word2vec.Vocab at 0x1077a5ef0>,
#  'organization': <gensim.models.word2vec.Vocab at 0x1077b8748>,
#  'buy': <gensim.models.word2vec.Vocab at 0x1077c8780>,
#  'messaging': <gensim.models.word2vec.Vocab at 0x1077aa518>,
#  'agreements': <gensim.models.word2vec.Vocab at 0x1077a5f28>,
#  'note': <gensim.models.word2vec.Vocab at 0x107796550>,
#  'backout': <gensim.models.word2vec.Vocab at 0x107796588>,
#  'donald': <gensim.models.word2vec.Vocab at 0x1077b87b8>,
#  'here': <gensim.models.word2vec.Vocab at 0x1077c87b8>,
#  'earlier': <gensim.models.word2vec.Vocab at 0x1077965c0>,
#  'ensure': <gensim.models.word2vec.Vocab at 0x1077a5f98>,
#  'coming': <gensim.models.word2vec.Vocab at 0x1077965f8>,
#  'anncenron': <gensim.models.word2vec.Vocab at 0x107796630>,
#  'cows': <gensim.models.word2vec.Vocab at 0x107796668>,
#  'card': <gensim.models.word2vec.Vocab at 0x1077a7048>,
#  'ubspw': <gensim.models.word2vec.Vocab at 0x1077a2ac8>,
#  'problems': <gensim.models.word2vec.Vocab at 0x1077966a0>,
#  'sce1': <gensim.models.word2vec.Vocab at 0x1077cd8d0>,
#  'traders': <gensim.models.word2vec.Vocab at 0x1077c87f0>,
#  'they': <gensim.models.word2vec.Vocab at 0x1077a7080>,
#  'jwebb': <gensim.models.word2vec.Vocab at 0x1077a70b8>,
#  'including': <gensim.models.word2vec.Vocab at 0x1077b8828>,
#  'jim': <gensim.models.word2vec.Vocab at 0x1077966d8>,
#  'world': <gensim.models.word2vec.Vocab at 0x1077b8860>,
#  'message': <gensim.models.word2vec.Vocab at 0x1077c85c0>,
#  'systems': <gensim.models.word2vec.Vocab at 0x1077cd5f8>,
#  'gets': <gensim.models.word2vec.Vocab at 0x107796710>,
#  'request': <gensim.models.word2vec.Vocab at 0x1077a70f0>,
#  'ldewett': <gensim.models.word2vec.Vocab at 0x1077b8898>,
#  'gabrielle': <gensim.models.word2vec.Vocab at 0x1077bdd30>,
#  'adahlke': <gensim.models.word2vec.Vocab at 0x1077b88d0>,
#  'bcc': <gensim.models.word2vec.Vocab at 0x10779a860>,
#  'cuts': <gensim.models.word2vec.Vocab at 0x1077c8898>,
#  'paso': <gensim.models.word2vec.Vocab at 0x1077c88d0>,
#  'purpose': <gensim.models.word2vec.Vocab at 0x1077c82b0>,
#  'christian': <gensim.models.word2vec.Vocab at 0x1077c8908>,
#  'samador': <gensim.models.word2vec.Vocab at 0x1077967b8>,
#  'pacheco': <gensim.models.word2vec.Vocab at 0x1077a21d0>,
#  'about': <gensim.models.word2vec.Vocab at 0x107798390>,
#  'hereto': <gensim.models.word2vec.Vocab at 0x1077967f0>,
#  'mtang': <gensim.models.word2vec.Vocab at 0x1077a7160>,
#  'mstokle': <gensim.models.word2vec.Vocab at 0x1077b8908>,
#  'juan': <gensim.models.word2vec.Vocab at 0x1077b0e10>,
#  'hayden': <gensim.models.word2vec.Vocab at 0x1077c89e8>,
#  'fitzgerald': <gensim.models.word2vec.Vocab at 0x1077d0240>,
#  'status': <gensim.models.word2vec.Vocab at 0x1077bf518>,
#  'during': <gensim.models.word2vec.Vocab at 0x1077c8a20>,
#  'sap': <gensim.models.word2vec.Vocab at 0x1077b8978>,
#  'availability': <gensim.models.word2vec.Vocab at 0x107796898>,
#  'mmansfie': <gensim.models.word2vec.Vocab at 0x1077a0ba8>,
#  'motuzko': <gensim.models.word2vec.Vocab at 0x1077968d0>,
#  'doing': <gensim.models.word2vec.Vocab at 0x1077bd550>,
#  'wolfe': <gensim.models.word2vec.Vocab at 0x1077ac7f0>,
#  'relevant': <gensim.models.word2vec.Vocab at 0x1077ac828>,
#  'recently': <gensim.models.word2vec.Vocab at 0x1077d07f0>,
#  '284': <gensim.models.word2vec.Vocab at 0x1077b89e8>,
#  'sheidun': <gensim.models.word2vec.Vocab at 0x1077d0390>,
#  'fchang': <gensim.models.word2vec.Vocab at 0x1077b8a20>,
#  'kathryn': <gensim.models.word2vec.Vocab at 0x107796978>,
#  'servers': <gensim.models.word2vec.Vocab at 0x1077a22e8>,
#  'phillip': <gensim.models.word2vec.Vocab at 0x1077969e8>,
#  'unify': <gensim.models.word2vec.Vocab at 0x1077cbef0>,
#  'psco': <gensim.models.word2vec.Vocab at 0x1077a7198>,
#  'kannantha': <gensim.models.word2vec.Vocab at 0x1077b8a58>,
#  'portlandrealtimeshift': <gensim.models.word2vec.Vocab at 0x1077a71d0>,
#  'carefully': <gensim.models.word2vec.Vocab at 0x1077c8a90>,
#  'oxley': <gensim.models.word2vec.Vocab at 0x1077b8a90>,
#  'francis': <gensim.models.word2vec.Vocab at 0x1077c8b00>,
#  'steve': <gensim.models.word2vec.Vocab at 0x1077a7208>,
#  'individual': <gensim.models.word2vec.Vocab at 0x1077a7240>,
#  'agreed': <gensim.models.word2vec.Vocab at 0x1077c8438>,
#  'reply': <gensim.models.word2vec.Vocab at 0x1077b8ac8>,
#  'claudia': <gensim.models.word2vec.Vocab at 0x107796be0>,
#  'rsmith': <gensim.models.word2vec.Vocab at 0x1077b0c18>,
#  'brennan': <gensim.models.word2vec.Vocab at 0x1077c8b38>,
#  'corporate': <gensim.models.word2vec.Vocab at 0x107796a20>,
#  'alan': <gensim.models.word2vec.Vocab at 0x1077a7278>,
#  'second': <gensim.models.word2vec.Vocab at 0x1077a72b0>,
#  'yang': <gensim.models.word2vec.Vocab at 0x1077a72e8>,
#  'outage': <gensim.models.word2vec.Vocab at 0x1077a7320>,
#  'restricted': <gensim.models.word2vec.Vocab at 0x1077a7358>,
#  'rvirnau': <gensim.models.word2vec.Vocab at 0x1077b8b38>,
#  'tickets': <gensim.models.word2vec.Vocab at 0x1077a7390>,
#  '327': <gensim.models.word2vec.Vocab at 0x1077c81d0>,
#  'impact': <gensim.models.word2vec.Vocab at 0x107796a58>,
#  'atc': <gensim.models.word2vec.Vocab at 0x1077d09e8>,
#  'kinser': <gensim.models.word2vec.Vocab at 0x107796a90>,
#  'years': <gensim.models.word2vec.Vocab at 0x1077cd048>,
#  'klattup': <gensim.models.word2vec.Vocab at 0x1077d0e10>,
#  'diane': <gensim.models.word2vec.Vocab at 0x1077d0f98>,
#  'bill': <gensim.models.word2vec.Vocab at 0x1077b3f28>,
#  'srp': <gensim.models.word2vec.Vocab at 0x1077b8b70>,
#  'goal': <gensim.models.word2vec.Vocab at 0x1077c8470>,
#  'seung': <gensim.models.word2vec.Vocab at 0x107796ac8>,
#  'jpowell': <gensim.models.word2vec.Vocab at 0x1077a7400>,
#  'addition': <gensim.models.word2vec.Vocab at 0x107796b00>,
#  'question': <gensim.models.word2vec.Vocab at 0x1077c8c50>,
#  'nolte': <gensim.models.word2vec.Vocab at 0x107796b38>,
#  'developed': <gensim.models.word2vec.Vocab at 0x107796b70>,
#  'vgadhavi': <gensim.models.word2vec.Vocab at 0x1077a7438>,
#  'cdean2': <gensim.models.word2vec.Vocab at 0x1077b8be0>,
#  'rewards': <gensim.models.word2vec.Vocab at 0x1077d2390>,
#  'receive': <gensim.models.word2vec.Vocab at 0x1077c8c88>,
#  'thanksgiving': <gensim.models.word2vec.Vocab at 0x1077c84e0>,
#  'lburnett': <gensim.models.word2vec.Vocab at 0x1077b09e8>,
#  'hal': <gensim.models.word2vec.Vocab at 0x1077a7470>,
#  'test': <gensim.models.word2vec.Vocab at 0x10779dbe0>,
#  'dsteine2': <gensim.models.word2vec.Vocab at 0x1077b0ac8>,
#  'valderrama': <gensim.models.word2vec.Vocab at 0x1077d0898>,
#  'assist': <gensim.models.word2vec.Vocab at 0x1077a06d8>,
#  'option': <gensim.models.word2vec.Vocab at 0x1077c8cc0>,
#  'fax': <gensim.models.word2vec.Vocab at 0x1077a74a8>,
#  'congestion': <gensim.models.word2vec.Vocab at 0x1077a74e0>,
#  'davies': <gensim.models.word2vec.Vocab at 0x1077b8c50>,
#  'didn': <gensim.models.word2vec.Vocab at 0x1077c8550>,
#  'jeremy': <gensim.models.word2vec.Vocab at 0x107796c18>,
#  'ongoing': <gensim.models.word2vec.Vocab at 0x1077c8d68>,
#  'woodland': <gensim.models.word2vec.Vocab at 0x1077c8da0>,
#  'sale': <gensim.models.word2vec.Vocab at 0x1077c8dd8>,
#  'while': <gensim.models.word2vec.Vocab at 0x1077b8c88>,
#  'fma': <gensim.models.word2vec.Vocab at 0x1077b8cc0>,
#  'rodriguez': <gensim.models.word2vec.Vocab at 0x1077c8e10>,
#  'filed': <gensim.models.word2vec.Vocab at 0x1077b3fd0>,
#  'bought': <gensim.models.word2vec.Vocab at 0x1077d2f60>,
#  'wang': <gensim.models.word2vec.Vocab at 0x107796c88>,
#  'lori': <gensim.models.word2vec.Vocab at 0x1077d02b0>,
#  'sps': <gensim.models.word2vec.Vocab at 0x1077c8e80>,
#  'opened': <gensim.models.word2vec.Vocab at 0x1077c8eb8>,
#  'kandaswamy': <gensim.models.word2vec.Vocab at 0x1077a2b00>,
#  'mouth': <gensim.models.word2vec.Vocab at 0x107796cc0>,
#  'originators': <gensim.models.word2vec.Vocab at 0x1077a7518>,
#  'avista': <gensim.models.word2vec.Vocab at 0x1077a7550>,
#  'ubs': <gensim.models.word2vec.Vocab at 0x1077a7588>,
#  'wife': <gensim.models.word2vec.Vocab at 0x1077a75c0>,
#  'ron': <gensim.models.word2vec.Vocab at 0x1077cb198>,
#  'doug': <gensim.models.word2vec.Vocab at 0x1077b5080>,
#  'procedures': <gensim.models.word2vec.Vocab at 0x107796cf8>,
#  'come': <gensim.models.word2vec.Vocab at 0x107796d30>,
#  'oss': <gensim.models.word2vec.Vocab at 0x1077b8d30>,
#  'occur': <gensim.models.word2vec.Vocab at 0x1077b3470>,
#  'bps4': <gensim.models.word2vec.Vocab at 0x1077b8d68>,
#  'franky': <gensim.models.word2vec.Vocab at 0x107796d68>,
#  'which': <gensim.models.word2vec.Vocab at 0x1077a76a0>,
#  'forms': <gensim.models.word2vec.Vocab at 0x1077b8da0>,
#  '97204': <gensim.models.word2vec.Vocab at 0x1077a76d8>,
#  'nwang': <gensim.models.word2vec.Vocab at 0x1077b35c0>,
#  'amelethi': <gensim.models.word2vec.Vocab at 0x1077c8fd0>,
#  'affiliate': <gensim.models.word2vec.Vocab at 0x107796dd8>,
#  'bwillia5': <gensim.models.word2vec.Vocab at 0x1077cb048>,
#  'plane': <gensim.models.word2vec.Vocab at 0x1077d6208>,
#  'and': <gensim.models.word2vec.Vocab at 0x1077a7710>,
#  'url': <gensim.models.word2vec.Vocab at 0x1077d62b0>,
#  'hood': <gensim.models.word2vec.Vocab at 0x1077d2c50>,
#  'ssinha': <gensim.models.word2vec.Vocab at 0x107796e10>,
#  'acomnes': <gensim.models.word2vec.Vocab at 0x1077cb080>,
#  'kptv': <gensim.models.word2vec.Vocab at 0x1077cb0b8>,
#  'savings': <gensim.models.word2vec.Vocab at 0x107796518>,
#  'whom': <gensim.models.word2vec.Vocab at 0x1077bf780>,
#  'deleted': <gensim.models.word2vec.Vocab at 0x1077cb128>,
#  'assistant': <gensim.models.word2vec.Vocab at 0x1077cb160>,
#  'transition': <gensim.models.word2vec.Vocab at 0x1077c6940>,
#  'f0070e6': <gensim.models.word2vec.Vocab at 0x1077cb748>,
#  'talk': <gensim.models.word2vec.Vocab at 0x1077aab38>,
#  'bring': <gensim.models.word2vec.Vocab at 0x107796390>,
#  'mguzman3': <gensim.models.word2vec.Vocab at 0x1077a0940>,
#  'gonzalez': <gensim.models.word2vec.Vocab at 0x107796e48>,
#  'attachments': <gensim.models.word2vec.Vocab at 0x107796e80>,
#  'pst': <gensim.models.word2vec.Vocab at 0x1077b8e48>,
#  'zhu': <gensim.models.word2vec.Vocab at 0x1077cb240>,
#  'right': <gensim.models.word2vec.Vocab at 0x1077a7780>,
#  'contributions': <gensim.models.word2vec.Vocab at 0x1077b3be0>,
#  '2001': <gensim.models.word2vec.Vocab at 0x107796eb8>,
#  '8000': <gensim.models.word2vec.Vocab at 0x1077b8eb8>,
#  'aps': <gensim.models.word2vec.Vocab at 0x1077c3cc0>,
#  'lay': <gensim.models.word2vec.Vocab at 0x1077cb320>,
#  'year': <gensim.models.word2vec.Vocab at 0x1077cd1d0>,
#  'fyi': <gensim.models.word2vec.Vocab at 0x1077b8ef0>,
#  'andrew': <gensim.models.word2vec.Vocab at 0x107796ef0>,
#  'stokley': <gensim.models.word2vec.Vocab at 0x1077c6f28>,
#  'resources': <gensim.models.word2vec.Vocab at 0x107796f28>,
#  'jmeyer': <gensim.models.word2vec.Vocab at 0x1077d6588>,
#  'south': <gensim.models.word2vec.Vocab at 0x1077b8f28>,
#  'interchange': <gensim.models.word2vec.Vocab at 0x1077cb7b8>,
#  'jay': <gensim.models.word2vec.Vocab at 0x107796f60>,
#  'pay': <gensim.models.word2vec.Vocab at 0x1077a77f0>,
#  'sundar': <gensim.models.word2vec.Vocab at 0x107793eb8>,
#  'workers': <gensim.models.word2vec.Vocab at 0x1077a7828>,
#  'couple': <gensim.models.word2vec.Vocab at 0x1077cb390>,
#  'sure': <gensim.models.word2vec.Vocab at 0x1077b8f60>,
#  'failure': <gensim.models.word2vec.Vocab at 0x1077ba2e8>,
#  'awoodlan': <gensim.models.word2vec.Vocab at 0x107795198>,
#  'transaction': <gensim.models.word2vec.Vocab at 0x1077a7898>,
#  'cecilia': <gensim.models.word2vec.Vocab at 0x1077cb3c8>,
#  'sanjeev': <gensim.models.word2vec.Vocab at 0x1077952e8>,
#  'zhuoming': <gensim.models.word2vec.Vocab at 0x1077a78d0>,
#  'adam': <gensim.models.word2vec.Vocab at 0x107798048>,
#  'finals': <gensim.models.word2vec.Vocab at 0x107795400>,
#  'tinvedy': <gensim.models.word2vec.Vocab at 0x1077a7908>,
#  'both': <gensim.models.word2vec.Vocab at 0x1077a7940>,
#  'original': <gensim.models.word2vec.Vocab at 0x1077b8f98>,
#  'nose': <gensim.models.word2vec.Vocab at 0x107798080>,
#  'jdasovic': <gensim.models.word2vec.Vocab at 0x1077cb438>,
#  'generation': <gensim.models.word2vec.Vocab at 0x1077cb470>,
#  'asked': <gensim.models.word2vec.Vocab at 0x1077bd6d8>,
#  'dollars': <gensim.models.word2vec.Vocab at 0x1077c6898>,
#  'good': <gensim.models.word2vec.Vocab at 0x1077a0978>,
#  'put': <gensim.models.word2vec.Vocab at 0x1077a79b0>,
#  'snat': <gensim.models.word2vec.Vocab at 0x1077bd710>,
#  'terris': <gensim.models.word2vec.Vocab at 0x1077a79e8>,
#  'unit': <gensim.models.word2vec.Vocab at 0x1077980f0>,
#  'not': <gensim.models.word2vec.Vocab at 0x1077a7a20>,
#  'product': <gensim.models.word2vec.Vocab at 0x1077ba0b8>,
#  'epmicalpool': <gensim.models.word2vec.Vocab at 0x1077ba0f0>,
#  'harrell': <gensim.models.word2vec.Vocab at 0x1077aa6d8>,
#  'ready': <gensim.models.word2vec.Vocab at 0x107798128>,
#  'email': <gensim.models.word2vec.Vocab at 0x107798160>,
#  'expected': <gensim.models.word2vec.Vocab at 0x1077cb518>,
#  'less': <gensim.models.word2vec.Vocab at 0x107798198>,
#  'evelyn': <gensim.models.word2vec.Vocab at 0x1077cb550>,
#  'export': <gensim.models.word2vec.Vocab at 0x107795da0>,
#  'resolution': <gensim.models.word2vec.Vocab at 0x1077ba128>,
#  'pge1': <gensim.models.word2vec.Vocab at 0x1077a7a90>,
#  'mgustaf': <gensim.models.word2vec.Vocab at 0x1077ba160>,
#  'few': <gensim.models.word2vec.Vocab at 0x1077b5ef0>,
#  'burra': <gensim.models.word2vec.Vocab at 0x1077cb5c0>,
#  'kearney': <gensim.models.word2vec.Vocab at 0x1077ba198>,
#  '5th': <gensim.models.word2vec.Vocab at 0x1077981d0>,
#  'quickly': <gensim.models.word2vec.Vocab at 0x107798208>,
#  'acceptance': <gensim.models.word2vec.Vocab at 0x107795f98>,
#  'ascii': <gensim.models.word2vec.Vocab at 0x1077b54a8>,
#  'through': <gensim.models.word2vec.Vocab at 0x1077a7b00>,
#  'month': <gensim.models.word2vec.Vocab at 0x107798278>,
#  'network': <gensim.models.word2vec.Vocab at 0x1077a7b38>,
#  'likely': <gensim.models.word2vec.Vocab at 0x107796400>,
#  '464': <gensim.models.word2vec.Vocab at 0x1077bf7b8>,
#  'villeggiante': <gensim.models.word2vec.Vocab at 0x1077982b0>,
#  'dasovich': <gensim.models.word2vec.Vocab at 0x1077a7b70>,
#  'jryan4': <gensim.models.word2vec.Vocab at 0x1077cb630>,
#  'mckinney': <gensim.models.word2vec.Vocab at 0x1077cb668>,
#  '9fc2e8ba': <gensim.models.word2vec.Vocab at 0x1077b8518>,
#  'being': <gensim.models.word2vec.Vocab at 0x1077ba1d0>,
#  'cbentle': <gensim.models.word2vec.Vocab at 0x107798320>,
#  'internet': <gensim.models.word2vec.Vocab at 0x1077a7ba8>,
#  'value': <gensim.models.word2vec.Vocab at 0x107798358>,
#  'lotus': <gensim.models.word2vec.Vocab at 0x1077ba208>,
#  'announcements': <gensim.models.word2vec.Vocab at 0x1077a7da0>,
#  'bnagar': <gensim.models.word2vec.Vocab at 0x1077b8588>,
#  'motley': <gensim.models.word2vec.Vocab at 0x1077983c8>,
#  'grant': <gensim.models.word2vec.Vocab at 0x1077cd710>,
#  'cum': <gensim.models.word2vec.Vocab at 0x1077ba240>,
#  'bfortne': <gensim.models.word2vec.Vocab at 0x1077ba278>,
#  'abler': <gensim.models.word2vec.Vocab at 0x107798400>,
#  'interested': <gensim.models.word2vec.Vocab at 0x107798438>,
#  'hien': <gensim.models.word2vec.Vocab at 0x1077b5198>,
#  'melethil': <gensim.models.word2vec.Vocab at 0x1077ba2b0>,
#  'holiday': <gensim.models.word2vec.Vocab at 0x1077984a8>,
#  'dronet': <gensim.models.word2vec.Vocab at 0x107796ba8>,
#  'brewer': <gensim.models.word2vec.Vocab at 0x1077984e0>,
#  'chitradurga': <gensim.models.word2vec.Vocab at 0x107798518>,
#  '8625656e': <gensim.models.word2vec.Vocab at 0x1077ba320>,
#  'foster': <gensim.models.word2vec.Vocab at 0x1077a7c88>,
#  'change': <gensim.models.word2vec.Vocab at 0x1077b8cf8>,
#  'between': <gensim.models.word2vec.Vocab at 0x1077a7cc0>,
#  'cards': <gensim.models.word2vec.Vocab at 0x1077cb6a0>,
#  '7bit': <gensim.models.word2vec.Vocab at 0x107796da0>,
#  'lee': <gensim.models.word2vec.Vocab at 0x1077a7cf8>,
#  'black': <gensim.models.word2vec.Vocab at 0x1077cb710>,
#  'werner': <gensim.models.word2vec.Vocab at 0x1077ba390>,
#  'info': <gensim.models.word2vec.Vocab at 0x1077cb780>,
#  'kysa': <gensim.models.word2vec.Vocab at 0x107798588>,
#  'min': <gensim.models.word2vec.Vocab at 0x1077985c0>,
#  'york': <gensim.models.word2vec.Vocab at 0x1077a7d30>,
#  'gsolber': <gensim.models.word2vec.Vocab at 0x1077b8fd0>,
#  'bnguyen2': <gensim.models.word2vec.Vocab at 0x1077cb7f0>,
#  'very': <gensim.models.word2vec.Vocab at 0x107798630>,
#  'home': <gensim.models.word2vec.Vocab at 0x1077c3e80>,
#  'bschneid': <gensim.models.word2vec.Vocab at 0x1077d0748>,
#  'decision': <gensim.models.word2vec.Vocab at 0x1077a7d68>,
#  'jmiller': <gensim.models.word2vec.Vocab at 0x107798668>,
#  'sometime': <gensim.models.word2vec.Vocab at 0x1077986a0>,
#  'ubswe': <gensim.models.word2vec.Vocab at 0x1077ba3c8>,
#  'week': <gensim.models.word2vec.Vocab at 0x1077ba400>,
#  'mansfield': <gensim.models.word2vec.Vocab at 0x1077c6eb8>,
#  'cschome': <gensim.models.word2vec.Vocab at 0x1077cb860>,
#  'mtaylo1': <gensim.models.word2vec.Vocab at 0x1077b85f8>,
#  'white': <gensim.models.word2vec.Vocab at 0x1077ba438>,
#  'property': <gensim.models.word2vec.Vocab at 0x1077cb8d0>,
#  'northwest': <gensim.models.word2vec.Vocab at 0x1077986d8>,
#  'tag': <gensim.models.word2vec.Vocab at 0x1077d2e10>,
#  'leading': <gensim.models.word2vec.Vocab at 0x1077ba470>,
#  'marci': <gensim.models.word2vec.Vocab at 0x1077a7dd8>,
#  'appropriate': <gensim.models.word2vec.Vocab at 0x1077cb908>,
#  'palo': <gensim.models.word2vec.Vocab at 0x1077cb940>,
#  'credit': <gensim.models.word2vec.Vocab at 0x1077cd0f0>,
#  'supply': <gensim.models.word2vec.Vocab at 0x1077ba4a8>,
#  'former': <gensim.models.word2vec.Vocab at 0x1077ba4e0>,
#  'bps3': <gensim.models.word2vec.Vocab at 0x1077a7e10>,
#  'david': <gensim.models.word2vec.Vocab at 0x1077ba518>,
#  'jthomas5': <gensim.models.word2vec.Vocab at 0x1077985f8>,
#  'however': <gensim.models.word2vec.Vocab at 0x1077ba588>,
#  'businesses': <gensim.models.word2vec.Vocab at 0x107798d68>,
#  'cevans': <gensim.models.word2vec.Vocab at 0x107798780>,
#  'personnel': <gensim.models.word2vec.Vocab at 0x1077ba5c0>,
#  'filled': <gensim.models.word2vec.Vocab at 0x1077ba5f8>,
#  'lewis': <gensim.models.word2vec.Vocab at 0x1077cb9b0>,
#  'guzman': <gensim.models.word2vec.Vocab at 0x1077987f0>,
#  'last': <gensim.models.word2vec.Vocab at 0x1077ba630>,
#  'mkt': <gensim.models.word2vec.Vocab at 0x1077cb9e8>,
#  'ajay': <gensim.models.word2vec.Vocab at 0x1077a7e48>,
#  'process': <gensim.models.word2vec.Vocab at 0x1077b5240>,
#  'shawn': <gensim.models.word2vec.Vocab at 0x107798860>,
#  'clackey2': <gensim.models.word2vec.Vocab at 0x1077a7e80>,
#  'steiner': <gensim.models.word2vec.Vocab at 0x1077bd160>,
#  'bruce': <gensim.models.word2vec.Vocab at 0x1077c6cf8>,
#  'deal': <gensim.models.word2vec.Vocab at 0x10779a400>,
#  'sorkina': <gensim.models.word2vec.Vocab at 0x107798898>,
#  'symms': <gensim.models.word2vec.Vocab at 0x1077a7eb8>,
#  'weekend': <gensim.models.word2vec.Vocab at 0x1077a7ef0>,
#  'enpower': <gensim.models.word2vec.Vocab at 0x1077988d0>,
#  'alport': <gensim.models.word2vec.Vocab at 0x107798908>,
#  'non': <gensim.models.word2vec.Vocab at 0x1077ba080>,
#  'inc': <gensim.models.word2vec.Vocab at 0x1077c3cf8>,
#  'cfoster': <gensim.models.word2vec.Vocab at 0x107798940>,
#  'model': <gensim.models.word2vec.Vocab at 0x1077ba710>,
#  'mable': <gensim.models.word2vec.Vocab at 0x107798978>,
#  'please': <gensim.models.word2vec.Vocab at 0x1077cb358>,
#  'karen': <gensim.models.word2vec.Vocab at 0x1077989b0>,
#  'duke': <gensim.models.word2vec.Vocab at 0x1077ba748>,
#  'jun': <gensim.models.word2vec.Vocab at 0x1077ba780>,
#  'tax': <gensim.models.word2vec.Vocab at 0x1077cba90>,
#  'what': <gensim.models.word2vec.Vocab at 0x1077cbac8>,
#  'hmckinne': <gensim.models.word2vec.Vocab at 0x1077ba7b8>,
#  'mlallani': <gensim.models.word2vec.Vocab at 0x1077989e8>,
#  'states': <gensim.models.word2vec.Vocab at 0x1077ba7f0>,
#  'area': <gensim.models.word2vec.Vocab at 0x1077d2978>,
#  'binding': <gensim.models.word2vec.Vocab at 0x10779aa20>,
#  'notesaddr': <gensim.models.word2vec.Vocab at 0x107798a20>,
#  'nguyen': <gensim.models.word2vec.Vocab at 0x107796828>,
#  'parsing': <gensim.models.word2vec.Vocab at 0x1077d6128>,
#  'should': <gensim.models.word2vec.Vocab at 0x1077ba828>,
#  'jshields': <gensim.models.word2vec.Vocab at 0x1077bda20>,
#  'want': <gensim.models.word2vec.Vocab at 0x1077ba668>,
#  'management': <gensim.models.word2vec.Vocab at 0x107798a58>,
#  'getting': <gensim.models.word2vec.Vocab at 0x1077aa080>,
#  'beginning': <gensim.models.word2vec.Vocab at 0x1077ba860>,
#  'than': <gensim.models.word2vec.Vocab at 0x1077cbb00>,
#  'resupply': <gensim.models.word2vec.Vocab at 0x107798a90>,
#  '9797': <gensim.models.word2vec.Vocab at 0x10779ac88>,
#  'meyers': <gensim.models.word2vec.Vocab at 0x107798ac8>,
#  'dean': <gensim.models.word2vec.Vocab at 0x107798b00>,
#  'face': <gensim.models.word2vec.Vocab at 0x1077aa0f0>,
#  'example': <gensim.models.word2vec.Vocab at 0x1077ba8d0>,
#  'address': <gensim.models.word2vec.Vocab at 0x1077ba908>,
#  'salad': <gensim.models.word2vec.Vocab at 0x1077b86a0>,
#  'sunday': <gensim.models.word2vec.Vocab at 0x107798b38>,
#  'sysadmiral': <gensim.models.word2vec.Vocab at 0x1077cd208>,
#  'center': <gensim.models.word2vec.Vocab at 0x1077cbb70>,
#  'zwei': <gensim.models.word2vec.Vocab at 0x107798b70>,
#  'sblaylo': <gensim.models.word2vec.Vocab at 0x1077ba940>,
#  'either': <gensim.models.word2vec.Vocab at 0x10779afd0>,
#  'jake': <gensim.models.word2vec.Vocab at 0x1077aa128>,
#  'chick': <gensim.models.word2vec.Vocab at 0x107798ba8>,
#  'big': <gensim.models.word2vec.Vocab at 0x1077ba978>,
#  'henry': <gensim.models.word2vec.Vocab at 0x1077cbba8>,
#  'exchange': <gensim.models.word2vec.Vocab at 0x1077b8160>,
#  'debra': <gensim.models.word2vec.Vocab at 0x1077aa198>,
#  'leonardo': <gensim.models.word2vec.Vocab at 0x1077c3978>,
#  'simulation': <gensim.models.word2vec.Vocab at 0x107798be0>,
#  'blow': <gensim.models.word2vec.Vocab at 0x107798c18>,
#  'clear': <gensim.models.word2vec.Vocab at 0x1077aa1d0>,
#  'jkinser': <gensim.models.word2vec.Vocab at 0x1077cb588>,
#  'cst': <gensim.models.word2vec.Vocab at 0x1077b3240>,
#  'performance': <gensim.models.word2vec.Vocab at 0x1077aa208>,
#  'grodriq': <gensim.models.word2vec.Vocab at 0x1077ba9e8>,
#  'sgupta2': <gensim.models.word2vec.Vocab at 0x1077cdba8>,
#  'content': <gensim.models.word2vec.Vocab at 0x107798c50>,
#  'then': <gensim.models.word2vec.Vocab at 0x1077b5550>,
#  'suvinay': <gensim.models.word2vec.Vocab at 0x1077baa20>,
#  'having': <gensim.models.word2vec.Vocab at 0x1077aa240>,
#  'richter': <gensim.models.word2vec.Vocab at 0x107798c88>,
#  'move': <gensim.models.word2vec.Vocab at 0x1077baa58>,
#  'additional': <gensim.models.word2vec.Vocab at 0x1077c3908>,
#  'nayan': <gensim.models.word2vec.Vocab at 0x1077964e0>,
#  'skannant': <gensim.models.word2vec.Vocab at 0x1077cbc50>,
#  'laurel': <gensim.models.word2vec.Vocab at 0x107798cc0>,
#  'counterparties': <gensim.models.word2vec.Vocab at 0x1077aa278>,
#  'dec': <gensim.models.word2vec.Vocab at 0x1077aa2b0>,
#  'points': <gensim.models.word2vec.Vocab at 0x1077baa90>,
#  'documents': <gensim.models.word2vec.Vocab at 0x107798cf8>,
#  'financial': <gensim.models.word2vec.Vocab at 0x10779db38>,
#  'swain': <gensim.models.word2vec.Vocab at 0x1077bab00>,
#  'distribution': <gensim.models.word2vec.Vocab at 0x1077acf60>,
#  'keep': <gensim.models.word2vec.Vocab at 0x107798d30>,
#  'since': <gensim.models.word2vec.Vocab at 0x1077cbcf8>,
#  'party': <gensim.models.word2vec.Vocab at 0x1077bab38>,
#  'attempt': <gensim.models.word2vec.Vocab at 0x10779dd30>,
#  'tom': <gensim.models.word2vec.Vocab at 0x1077aa320>,
#  'went': <gensim.models.word2vec.Vocab at 0x1077cbd30>,
#  '8001': <gensim.models.word2vec.Vocab at 0x1077bab70>,
#  'perform': <gensim.models.word2vec.Vocab at 0x107798da0>,
#  'tallen': <gensim.models.word2vec.Vocab at 0x1077b52b0>,
#  'health': <gensim.models.word2vec.Vocab at 0x1077aa358>,
#  'october': <gensim.models.word2vec.Vocab at 0x107798e10>,
#  'payroll': <gensim.models.word2vec.Vocab at 0x1077aa390>,
#  'cara': <gensim.models.word2vec.Vocab at 0x1077d0a90>,
#  'stock': <gensim.models.word2vec.Vocab at 0x1077cbda0>,
#  'bradford': <gensim.models.word2vec.Vocab at 0x1077cbdd8>,
#  'pizza': <gensim.models.word2vec.Vocab at 0x1077babe0>,
#  'certain': <gensim.models.word2vec.Vocab at 0x1077aa3c8>,
#  'best': <gensim.models.word2vec.Vocab at 0x1077bac18>,
#  'approval': <gensim.models.word2vec.Vocab at 0x107798e48>,
#  'vinson': <gensim.models.word2vec.Vocab at 0x1077987b8>,
#  'max': <gensim.models.word2vec.Vocab at 0x1077aa400>,
#  'attention': <gensim.models.word2vec.Vocab at 0x1077a02e8>,
#  'thanks': <gensim.models.word2vec.Vocab at 0x1077bac50>,
#  'endhour': <gensim.models.word2vec.Vocab at 0x1077d0b00>,
#  'perhaps': <gensim.models.word2vec.Vocab at 0x107798e80>,
#  'peterson': <gensim.models.word2vec.Vocab at 0x1077bac88>,
#  'btung': <gensim.models.word2vec.Vocab at 0x107798eb8>,
#  'workspace': <gensim.models.word2vec.Vocab at 0x107798ef0>,
#  'rebuild': <gensim.models.word2vec.Vocab at 0x107798f28>,
#  'rorschach': <gensim.models.word2vec.Vocab at 0x1077aa470>,
#  'report': <gensim.models.word2vec.Vocab at 0x1077bacc0>,
#  'via': <gensim.models.word2vec.Vocab at 0x107798f98>,
#  'westdesksupport': <gensim.models.word2vec.Vocab at 0x1077aa4e0>,
#  'possible': <gensim.models.word2vec.Vocab at 0x1077bacf8>,
#  'hennessy': <gensim.models.word2vec.Vocab at 0x1077bad30>,
#  'transmission': <gensim.models.word2vec.Vocab at 0x1077bad68>,
#  'kept': <gensim.models.word2vec.Vocab at 0x1077aa550>,
#  'kourtney': <gensim.models.word2vec.Vocab at 0x1077bada0>,
#  'log': <gensim.models.word2vec.Vocab at 0x1077cbe80>,
#  'rburra': <gensim.models.word2vec.Vocab at 0x1077c3748>,
#  'pdavis1': <gensim.models.word2vec.Vocab at 0x10779a048>,
#  'mollyadams123': <gensim.models.word2vec.Vocab at 0x1077badd8>,
#  'bhupesh': <gensim.models.word2vec.Vocab at 0x10779a080>,
#  'quarter': <gensim.models.word2vec.Vocab at 0x1077aa588>,
#  'taking': <gensim.models.word2vec.Vocab at 0x10779a0b8>,
#  'matt': <gensim.models.word2vec.Vocab at 0x10779db70>,
#  'intended': <gensim.models.word2vec.Vocab at 0x1077aa5c0>,
#  'evidence': <gensim.models.word2vec.Vocab at 0x1077cd198>,
#  'with': <gensim.models.word2vec.Vocab at 0x10779a0f0>,
#  'stay': <gensim.models.word2vec.Vocab at 0x1077aa5f8>,
#  'champion': <gensim.models.word2vec.Vocab at 0x1077bae48>,
#  'mcash': <gensim.models.word2vec.Vocab at 0x1077bd908>,
#  'gupta': <gensim.models.word2vec.Vocab at 0x1077bae80>,
#  'offices': <gensim.models.word2vec.Vocab at 0x1077aa668>,
#  'mai': <gensim.models.word2vec.Vocab at 0x1077cbf60>,
#  'iii': <gensim.models.word2vec.Vocab at 0x1077aa6a0>,
#  'tjones': <gensim.models.word2vec.Vocab at 0x1077baeb8>,
#  'payments': <gensim.models.word2vec.Vocab at 0x1077baef0>,
#  'fhayden': <gensim.models.word2vec.Vocab at 0x1077a0e80>,
#  'formed': <gensim.models.word2vec.Vocab at 0x1077b53c8>,
#  'machine': <gensim.models.word2vec.Vocab at 0x1077baf28>,
#  'cali': <gensim.models.word2vec.Vocab at 0x1077bfa58>,
#  'shields': <gensim.models.word2vec.Vocab at 0x1077aa710>,
#  'car': <gensim.models.word2vec.Vocab at 0x1077baf60>,
#  'cock': <gensim.models.word2vec.Vocab at 0x1077cd080>,
#  'nahou': <gensim.models.word2vec.Vocab at 0x1077baf98>,
#  'intend': <gensim.models.word2vec.Vocab at 0x1077cd0b8>,
#  'tim': <gensim.models.word2vec.Vocab at 0x1077aa748>,
#  'infrastructure': <gensim.models.word2vec.Vocab at 0x10779a1d0>,
#  'americans': <gensim.models.word2vec.Vocab at 0x1077aa780>,
#  'neil': <gensim.models.word2vec.Vocab at 0x1077c3f98>,
#  'vijay': <gensim.models.word2vec.Vocab at 0x1077cd160>,
#  'amy': <gensim.models.word2vec.Vocab at 0x1077bafd0>,
#  'transit': <gensim.models.word2vec.Vocab at 0x1077bd048>,
#  'jsteph1': <gensim.models.word2vec.Vocab at 0x1077c6128>,
#  'percent': <gensim.models.word2vec.Vocab at 0x1077aa7b8>,
#  'worldwide3': <gensim.models.word2vec.Vocab at 0x1077aa7f0>,
#  'submit': <gensim.models.word2vec.Vocab at 0x10779a208>,
#  'each': <gensim.models.word2vec.Vocab at 0x1077a07b8>,
#  'wente': <gensim.models.word2vec.Vocab at 0x1077aa828>,
#  'govindasamy': <gensim.models.word2vec.Vocab at 0x1077b5438>,
#  'using': <gensim.models.word2vec.Vocab at 0x10779a240>,
#  'ancillary': <gensim.models.word2vec.Vocab at 0x1077cd240>,
#  'data': <gensim.models.word2vec.Vocab at 0x1077aa860>,
#  'takes': <gensim.models.word2vec.Vocab at 0x1077bd0b8>,
#  'direct': <gensim.models.word2vec.Vocab at 0x10779a278>,
#  'busy': <gensim.models.word2vec.Vocab at 0x1077cd278>,
#  'position': <gensim.models.word2vec.Vocab at 0x10779a2b0>,
#  'trans': <gensim.models.word2vec.Vocab at 0x10779a2e8>,
#  'accept': <gensim.models.word2vec.Vocab at 0x10779de48>,
#  'merrell': <gensim.models.word2vec.Vocab at 0x1077aa898>,
#  'start': <gensim.models.word2vec.Vocab at 0x1077aa8d0>,
#  'bankruptcy': <gensim.models.word2vec.Vocab at 0x1077cd2b0>,
#  'provided': <gensim.models.word2vec.Vocab at 0x1077cd2e8>,
#  'before': <gensim.models.word2vec.Vocab at 0x1077bd128>,
#  'sql': <gensim.models.word2vec.Vocab at 0x10779a320>,
#  'morning': <gensim.models.word2vec.Vocab at 0x10779a358>,
#  'passes': <gensim.models.word2vec.Vocab at 0x1077cd358>,
#  'jhodge': <gensim.models.word2vec.Vocab at 0x1077cd390>,
#  'become': <gensim.models.word2vec.Vocab at 0x1077c69b0>,
#  'enron': <gensim.models.word2vec.Vocab at 0x1077aa940>,
#  'trouble': <gensim.models.word2vec.Vocab at 0x1077aa978>,
#  'steffes': <gensim.models.word2vec.Vocab at 0x10779a390>,
#  'let': <gensim.models.word2vec.Vocab at 0x1077aa9b0>,
#  'some': <gensim.models.word2vec.Vocab at 0x1077bd208>,
#  'downtown': <gensim.models.word2vec.Vocab at 0x1077bd240>,
#  'kate': <gensim.models.word2vec.Vocab at 0x1077a5048>,
#  'bryce': <gensim.models.word2vec.Vocab at 0x1077a50f0>,
#  'further': <gensim.models.word2vec.Vocab at 0x1077bd278>,
#  'adocwra': <gensim.models.word2vec.Vocab at 0x1077aaa20>,
#  'heizenrader': <gensim.models.word2vec.Vocab at 0x1077bd2b0>,
#  'howard': <gensim.models.word2vec.Vocab at 0x10779a3c8>,
#  'rao': <gensim.models.word2vec.Vocab at 0x1077c6ba8>,
#  'reason': <gensim.models.word2vec.Vocab at 0x1077bd2e8>,
#  'confidential': <gensim.models.word2vec.Vocab at 0x1077bd320>,
#  'works': <gensim.models.word2vec.Vocab at 0x1077aaa58>,
#  'food': <gensim.models.word2vec.Vocab at 0x1077d2828>,
#  'those': <gensim.models.word2vec.Vocab at 0x1077aaa90>,
#  'msn': <gensim.models.word2vec.Vocab at 0x1077aaac8>,
#  'increases': <gensim.models.word2vec.Vocab at 0x1077aab00>,
#  'found': <gensim.models.word2vec.Vocab at 0x10779a438>,
#  'watsonwyatt': <gensim.models.word2vec.Vocab at 0x1077cd470>,
#  'kasaru': <gensim.models.word2vec.Vocab at 0x10779a470>,
#  'ecthou': <gensim.models.word2vec.Vocab at 0x1077a54a8>,
#  'information': <gensim.models.word2vec.Vocab at 0x1077aab70>,
#  'material': <gensim.models.word2vec.Vocab at 0x1077bd358>,
#  'doggy': <gensim.models.word2vec.Vocab at 0x1077d0940>,
#  'syang': <gensim.models.word2vec.Vocab at 0x1077aaba8>,
#  'local': <gensim.models.word2vec.Vocab at 0x1077cd4a8>,
#  'eric': <gensim.models.word2vec.Vocab at 0x1077cd4e0>,
#  'jerrigo': <gensim.models.word2vec.Vocab at 0x1077aabe0>,
#  'therefore': <gensim.models.word2vec.Vocab at 0x1077aac18>,
#  'wei': <gensim.models.word2vec.Vocab at 0x1077aac50>,
#  'manager': <gensim.models.word2vec.Vocab at 0x1077aac88>,
#  'people': <gensim.models.word2vec.Vocab at 0x1077c8128>,
#  'salisbury': <gensim.models.word2vec.Vocab at 0x107796908>,
#  'accounts': <gensim.models.word2vec.Vocab at 0x10779a4a8>,
#  'matthew': <gensim.models.word2vec.Vocab at 0x1077aacc0>,
#  'sessions': <gensim.models.word2vec.Vocab at 0x1077aacf8>,
#  'officechairman': <gensim.models.word2vec.Vocab at 0x1077a0c88>,
#  'small': <gensim.models.word2vec.Vocab at 0x10779a4e0>,
#  'september': <gensim.models.word2vec.Vocab at 0x10779a518>,
#  'mid': <gensim.models.word2vec.Vocab at 0x1077d0c18>,
#  'wscc': <gensim.models.word2vec.Vocab at 0x1077aad68>,
#  'tags': <gensim.models.word2vec.Vocab at 0x10779a550>,
#  'forced': <gensim.models.word2vec.Vocab at 0x10779a588>,
#  'matter': <gensim.models.word2vec.Vocab at 0x10779a5c0>,
#  'north': <gensim.models.word2vec.Vocab at 0x1077aadd8>,
#  'over': <gensim.models.word2vec.Vocab at 0x1077bd400>,
#  'peter': <gensim.models.word2vec.Vocab at 0x10779a5f8>,
#  'drobins': <gensim.models.word2vec.Vocab at 0x1077bd438>,
#  'presto': <gensim.models.word2vec.Vocab at 0x10779a630>,
#  'stress': <gensim.models.word2vec.Vocab at 0x1077bd470>,
#  'bids': <gensim.models.word2vec.Vocab at 0x1077a5fd0>,
#  'worldwide2': <gensim.models.word2vec.Vocab at 0x1077cda90>,
#  'girl': <gensim.models.word2vec.Vocab at 0x1077bd4a8>,
#  'changes': <gensim.models.word2vec.Vocab at 0x1077bd4e0>,
#  'transfer': <gensim.models.word2vec.Vocab at 0x1077bd518>,
#  ...}

# %%
model.init_sims(replace=True)  # trim model when done training
model.save(os.path.expanduser('~/Downloads/w2v_enron_meyers_taylor.model'))
